# %% [markdown]
# # Cifar-10 이미지 분류 v2
# - 데이터 부풀리기

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,   # set input mean to 0 over the dataset
    samplewise_center=False,    # set each sample mean to 0
    featurewise_std_normalization=False,    # divide inputs by std of dataset
    samplewise_std_normalization=False,     # divide each input by its std
    zca_whitening=False,    # apply ZCA whitening
    zca_epsilon=1e-06,      # epsilon for ZCA whitening
    rotation_range=0,       # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally
    height_shift_range=0.1, # randomly shift images vertically
    shear_range=0.,         # set range for random shear
    zoom_range=0.1,         # set range for random zoom
    channel_shift_range=0., # set range for random channel shifts
    fill_mode='nearest',    # set mode for filling points outside the input boundaries
    cval=0.,                # value used for fill_mode = "constant"
    horizontal_flip=True,   # randomly flip images
    vertical_flip=False,    # randomly flip images
    rescale=None,           # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,    # set function that will be applied on each input
    data_format=None,       # image data format, either "channels_first" or "channels_last"
    validation_split=0.0    # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid),
    epochs=100, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.59038, saving model to best-cifar10-v2.h5
# 1250/1250 - 36s - loss: 1.8864 - accuracy: 0.3042 - val_loss: 1.5904 - val_accuracy: 0.4301 - 36s/epoch - 28ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.59038 to 1.41901, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.6084 - accuracy: 0.4099 - val_loss: 1.4190 - val_accuracy: 0.4898 - 21s/epoch - 17ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.41901 to 1.34318, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.4968 - accuracy: 0.4555 - val_loss: 1.3432 - val_accuracy: 0.5186 - 20s/epoch - 16ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.34318 to 1.23328, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.4194 - accuracy: 0.4872 - val_loss: 1.2333 - val_accuracy: 0.5554 - 21s/epoch - 17ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.23328
# 1250/1250 - 21s - loss: 1.3541 - accuracy: 0.5123 - val_loss: 1.2683 - val_accuracy: 0.5539 - 21s/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.23328 to 1.22436, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.3023 - accuracy: 0.5368 - val_loss: 1.2244 - val_accuracy: 0.5674 - 21s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.22436 to 1.10903, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.2549 - accuracy: 0.5544 - val_loss: 1.1090 - val_accuracy: 0.6073 - 20s/epoch - 16ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.10903 to 1.07328, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2166 - accuracy: 0.5666 - val_loss: 1.0733 - val_accuracy: 0.6165 - 21s/epoch - 16ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 1.07328 to 1.05038, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.1787 - accuracy: 0.5802 - val_loss: 1.0504 - val_accuracy: 0.6318 - 20s/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 1.05038 to 1.02090, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.1455 - accuracy: 0.5952 - val_loss: 1.0209 - val_accuracy: 0.6389 - 21s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 1.02090 to 0.99522, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.1233 - accuracy: 0.6038 - val_loss: 0.9952 - val_accuracy: 0.6493 - 21s/epoch - 17ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.99522 to 0.94837, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.0967 - accuracy: 0.6138 - val_loss: 0.9484 - val_accuracy: 0.6626 - 21s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.94837 to 0.91683, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0768 - accuracy: 0.6216 - val_loss: 0.9168 - val_accuracy: 0.6726 - 20s/epoch - 16ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.91683
# 1250/1250 - 21s - loss: 1.0528 - accuracy: 0.6310 - val_loss: 0.9190 - val_accuracy: 0.6770 - 21s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.91683
# 1250/1250 - 21s - loss: 1.0346 - accuracy: 0.6356 - val_loss: 0.9970 - val_accuracy: 0.6574 - 21s/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.91683 to 0.91596, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0244 - accuracy: 0.6407 - val_loss: 0.9160 - val_accuracy: 0.6777 - 20s/epoch - 16ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.91596
# 1250/1250 - 21s - loss: 1.0038 - accuracy: 0.6490 - val_loss: 0.9165 - val_accuracy: 0.6822 - 21s/epoch - 16ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.91596 to 0.87621, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.9892 - accuracy: 0.6522 - val_loss: 0.8762 - val_accuracy: 0.6957 - 21s/epoch - 17ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.87621
# 1250/1250 - 21s - loss: 0.9755 - accuracy: 0.6611 - val_loss: 0.8845 - val_accuracy: 0.6920 - 21s/epoch - 17ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.87621
# 1250/1250 - 21s - loss: 0.9613 - accuracy: 0.6620 - val_loss: 0.8934 - val_accuracy: 0.6881 - 21s/epoch - 16ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.87621 to 0.82412, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.9481 - accuracy: 0.6699 - val_loss: 0.8241 - val_accuracy: 0.7124 - 21s/epoch - 17ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.82412
# 1250/1250 - 21s - loss: 0.9385 - accuracy: 0.6754 - val_loss: 0.8264 - val_accuracy: 0.7141 - 21s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.82412 to 0.82299, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9307 - accuracy: 0.6742 - val_loss: 0.8230 - val_accuracy: 0.7126 - 20s/epoch - 16ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.82299
# 1250/1250 - 20s - loss: 0.9168 - accuracy: 0.6801 - val_loss: 0.8315 - val_accuracy: 0.7105 - 20s/epoch - 16ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.82299
# 1250/1250 - 20s - loss: 0.9135 - accuracy: 0.6825 - val_loss: 0.8487 - val_accuracy: 0.7090 - 20s/epoch - 16ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.82299 to 0.78454, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.9038 - accuracy: 0.6841 - val_loss: 0.7845 - val_accuracy: 0.7277 - 21s/epoch - 16ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.78454
# 1250/1250 - 21s - loss: 0.8855 - accuracy: 0.6900 - val_loss: 0.8022 - val_accuracy: 0.7194 - 21s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.78454
# 1250/1250 - 20s - loss: 0.8887 - accuracy: 0.6911 - val_loss: 0.8507 - val_accuracy: 0.7059 - 20s/epoch - 16ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.78454
# 1250/1250 - 20s - loss: 0.8832 - accuracy: 0.6937 - val_loss: 0.8202 - val_accuracy: 0.7139 - 20s/epoch - 16ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.78454
# 1250/1250 - 20s - loss: 0.8763 - accuracy: 0.6949 - val_loss: 0.7987 - val_accuracy: 0.7275 - 20s/epoch - 16ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.78454 to 0.77389, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8691 - accuracy: 0.6975 - val_loss: 0.7739 - val_accuracy: 0.7347 - 21s/epoch - 16ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.77389 to 0.75742, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8666 - accuracy: 0.7001 - val_loss: 0.7574 - val_accuracy: 0.7381 - 21s/epoch - 17ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.75742
# 1250/1250 - 20s - loss: 0.8636 - accuracy: 0.7012 - val_loss: 0.7751 - val_accuracy: 0.7314 - 20s/epoch - 16ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.75742
# 1250/1250 - 21s - loss: 0.8563 - accuracy: 0.7035 - val_loss: 0.8041 - val_accuracy: 0.7252 - 21s/epoch - 17ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.75742
# 1250/1250 - 20s - loss: 0.8501 - accuracy: 0.7049 - val_loss: 0.7970 - val_accuracy: 0.7231 - 20s/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.75742 to 0.74520, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8474 - accuracy: 0.7069 - val_loss: 0.7452 - val_accuracy: 0.7466 - 21s/epoch - 16ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.74520
# 1250/1250 - 21s - loss: 0.8452 - accuracy: 0.7092 - val_loss: 0.7729 - val_accuracy: 0.7328 - 21s/epoch - 16ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.74520
# 1250/1250 - 20s - loss: 0.8440 - accuracy: 0.7098 - val_loss: 0.7557 - val_accuracy: 0.7391 - 20s/epoch - 16ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.74520 to 0.73699, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8415 - accuracy: 0.7101 - val_loss: 0.7370 - val_accuracy: 0.7477 - 20s/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.73699
# 1250/1250 - 21s - loss: 0.8359 - accuracy: 0.7126 - val_loss: 0.7606 - val_accuracy: 0.7398 - 21s/epoch - 16ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.73699 to 0.73631, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8263 - accuracy: 0.7172 - val_loss: 0.7363 - val_accuracy: 0.7458 - 20s/epoch - 16ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.73631 to 0.73130, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8297 - accuracy: 0.7174 - val_loss: 0.7313 - val_accuracy: 0.7485 - 20s/epoch - 16ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.73130
# 1250/1250 - 20s - loss: 0.8241 - accuracy: 0.7157 - val_loss: 0.7892 - val_accuracy: 0.7367 - 20s/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.73130
# 1250/1250 - 20s - loss: 0.8243 - accuracy: 0.7181 - val_loss: 0.7785 - val_accuracy: 0.7283 - 20s/epoch - 16ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.73130
# 1250/1250 - 20s - loss: 0.8259 - accuracy: 0.7191 - val_loss: 0.7452 - val_accuracy: 0.7464 - 20s/epoch - 16ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.73130
# 1250/1250 - 21s - loss: 0.8237 - accuracy: 0.7188 - val_loss: 0.8163 - val_accuracy: 0.7310 - 21s/epoch - 16ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.73130
# 1250/1250 - 21s - loss: 0.8188 - accuracy: 0.7206 - val_loss: 0.7875 - val_accuracy: 0.7300 - 21s/epoch - 16ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.73130 to 0.72536, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8212 - accuracy: 0.7189 - val_loss: 0.7254 - val_accuracy: 0.7546 - 21s/epoch - 16ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.72536
# 1250/1250 - 20s - loss: 0.8092 - accuracy: 0.7225 - val_loss: 0.7678 - val_accuracy: 0.7509 - 20s/epoch - 16ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.72536
# 1250/1250 - 20s - loss: 0.8108 - accuracy: 0.7228 - val_loss: 0.7270 - val_accuracy: 0.7516 - 20s/epoch - 16ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.72536 to 0.71831, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8104 - accuracy: 0.7237 - val_loss: 0.7183 - val_accuracy: 0.7587 - 20s/epoch - 16ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.71831
# 1250/1250 - 21s - loss: 0.8105 - accuracy: 0.7225 - val_loss: 0.7857 - val_accuracy: 0.7362 - 21s/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.71831 to 0.71089, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8109 - accuracy: 0.7221 - val_loss: 0.7109 - val_accuracy: 0.7636 - 20s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.71089
# 1250/1250 - 20s - loss: 0.8135 - accuracy: 0.7231 - val_loss: 0.7732 - val_accuracy: 0.7453 - 20s/epoch - 16ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.71089
# 1250/1250 - 20s - loss: 0.8024 - accuracy: 0.7276 - val_loss: 0.7256 - val_accuracy: 0.7595 - 20s/epoch - 16ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.71089
# 1250/1250 - 20s - loss: 0.8104 - accuracy: 0.7242 - val_loss: 0.8294 - val_accuracy: 0.7315 - 20s/epoch - 16ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.71089 to 0.70949, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8032 - accuracy: 0.7258 - val_loss: 0.7095 - val_accuracy: 0.7657 - 20s/epoch - 16ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.70949
# 1250/1250 - 21s - loss: 0.8034 - accuracy: 0.7271 - val_loss: 0.7215 - val_accuracy: 0.7658 - 21s/epoch - 17ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.70949 to 0.70490, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8050 - accuracy: 0.7280 - val_loss: 0.7049 - val_accuracy: 0.7630 - 20s/epoch - 16ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.70490
# 1250/1250 - 20s - loss: 0.7981 - accuracy: 0.7309 - val_loss: 0.7466 - val_accuracy: 0.7527 - 20s/epoch - 16ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.70490
# 1250/1250 - 21s - loss: 0.8003 - accuracy: 0.7255 - val_loss: 0.7593 - val_accuracy: 0.7552 - 21s/epoch - 16ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.70490
# 1250/1250 - 20s - loss: 0.7977 - accuracy: 0.7309 - val_loss: 0.7357 - val_accuracy: 0.7506 - 20s/epoch - 16ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.70490 to 0.69876, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.7983 - accuracy: 0.7305 - val_loss: 0.6988 - val_accuracy: 0.7650 - 20s/epoch - 16ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.69876
# 1250/1250 - 20s - loss: 0.7983 - accuracy: 0.7293 - val_loss: 0.7428 - val_accuracy: 0.7512 - 20s/epoch - 16ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.69876
# 1250/1250 - 20s - loss: 0.7974 - accuracy: 0.7286 - val_loss: 0.7985 - val_accuracy: 0.7387 - 20s/epoch - 16ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.69876
# 1250/1250 - 20s - loss: 0.7988 - accuracy: 0.7295 - val_loss: 0.7348 - val_accuracy: 0.7523 - 20s/epoch - 16ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.69876
# 1250/1250 - 20s - loss: 0.7981 - accuracy: 0.7302 - val_loss: 0.7268 - val_accuracy: 0.7591 - 20s/epoch - 16ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.69876
# 1250/1250 - 20s - loss: 0.7951 - accuracy: 0.7345 - val_loss: 0.7705 - val_accuracy: 0.7431 - 20s/epoch - 16ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.69876 to 0.68736, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.7940 - accuracy: 0.7315 - val_loss: 0.6874 - val_accuracy: 0.7709 - 20s/epoch - 16ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7884 - accuracy: 0.7349 - val_loss: 0.7072 - val_accuracy: 0.7636 - 20s/epoch - 16ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7880 - accuracy: 0.7347 - val_loss: 0.7807 - val_accuracy: 0.7439 - 20s/epoch - 16ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7936 - accuracy: 0.7350 - val_loss: 0.7418 - val_accuracy: 0.7540 - 20s/epoch - 16ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7972 - accuracy: 0.7315 - val_loss: 0.7791 - val_accuracy: 0.7470 - 20s/epoch - 16ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7932 - accuracy: 0.7337 - val_loss: 0.7499 - val_accuracy: 0.7688 - 20s/epoch - 16ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7924 - accuracy: 0.7315 - val_loss: 0.7306 - val_accuracy: 0.7615 - 20s/epoch - 16ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.68736
# 1250/1250 - 21s - loss: 0.7901 - accuracy: 0.7313 - val_loss: 0.7152 - val_accuracy: 0.7655 - 21s/epoch - 16ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.68736
# 1250/1250 - 20s - loss: 0.7945 - accuracy: 0.7315 - val_loss: 0.6995 - val_accuracy: 0.7641 - 20s/epoch - 16ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.68736 to 0.68047, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.7914 - accuracy: 0.7349 - val_loss: 0.6805 - val_accuracy: 0.7781 - 20s/epoch - 16ms/step
# Epoch 79/100
#
# Epoch 00079: val_loss improved from 0.68047 to 0.67114, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.7868 - accuracy: 0.7377 - val_loss: 0.6711 - val_accuracy: 0.7832 - 20s/epoch - 16ms/step
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7889 - accuracy: 0.7332 - val_loss: 0.7166 - val_accuracy: 0.7712 - 20s/epoch - 16ms/step
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.67114
# 1250/1250 - 21s - loss: 0.7887 - accuracy: 0.7352 - val_loss: 0.9842 - val_accuracy: 0.7032 - 21s/epoch - 16ms/step
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7905 - accuracy: 0.7332 - val_loss: 0.7947 - val_accuracy: 0.7348 - 20s/epoch - 16ms/step
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7901 - accuracy: 0.7361 - val_loss: 0.7415 - val_accuracy: 0.7579 - 20s/epoch - 16ms/step
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7903 - accuracy: 0.7359 - val_loss: 0.7422 - val_accuracy: 0.7596 - 20s/epoch - 16ms/step
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7977 - accuracy: 0.7327 - val_loss: 0.7278 - val_accuracy: 0.7678 - 20s/epoch - 16ms/step
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7921 - accuracy: 0.7340 - val_loss: 0.7588 - val_accuracy: 0.7521 - 20s/epoch - 16ms/step
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7921 - accuracy: 0.7350 - val_loss: 0.7925 - val_accuracy: 0.7439 - 20s/epoch - 16ms/step
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7925 - accuracy: 0.7326 - val_loss: 0.7666 - val_accuracy: 0.7500 - 20s/epoch - 16ms/step
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.67114
# 1250/1250 - 20s - loss: 0.7940 - accuracy: 0.7349 - val_loss: 0.7248 - val_accuracy: 0.7823 - 20s/epoch - 16ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6851 - accuracy: 0.7746
# [0.6851389408111572, 0.7746000289916992]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
