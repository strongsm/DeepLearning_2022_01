# %% [markdown]
# # Cifar-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i])
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5), 
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.57572, saving model to best-cifar10-v1.h5
# 1250/1250 - 32s - loss: 1.8288 - accuracy: 0.3279 - val_loss: 1.5757 - val_accuracy: 0.4275 - 32s/epoch - 26ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.57572 to 1.38082, saving model to best-cifar10-v1.h5
# 1250/1250 - 19s - loss: 1.5220 - accuracy: 0.4424 - val_loss: 1.3808 - val_accuracy: 0.5053 - 19s/epoch - 15ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.38082 to 1.26895, saving model to best-cifar10-v1.h5
# 1250/1250 - 19s - loss: 1.3954 - accuracy: 0.4949 - val_loss: 1.2689 - val_accuracy: 0.5564 - 19s/epoch - 15ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.26895 to 1.23953, saving model to best-cifar10-v1.h5
# 1250/1250 - 19s - loss: 1.2975 - accuracy: 0.5352 - val_loss: 1.2395 - val_accuracy: 0.5559 - 19s/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.23953 to 1.19313, saving model to best-cifar10-v1.h5
# 1250/1250 - 20s - loss: 1.2173 - accuracy: 0.5652 - val_loss: 1.1931 - val_accuracy: 0.5838 - 20s/epoch - 16ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.19313 to 1.05812, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.1547 - accuracy: 0.5928 - val_loss: 1.0581 - val_accuracy: 0.6300 - 22s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.05812
# 1250/1250 - 21s - loss: 1.1005 - accuracy: 0.6152 - val_loss: 1.0682 - val_accuracy: 0.6215 - 21s/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.05812 to 0.97956, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.0553 - accuracy: 0.6304 - val_loss: 0.9796 - val_accuracy: 0.6557 - 22s/epoch - 18ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.97956 to 0.97202, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.0133 - accuracy: 0.6477 - val_loss: 0.9720 - val_accuracy: 0.6590 - 21s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.97202
# 1250/1250 - 21s - loss: 0.9791 - accuracy: 0.6586 - val_loss: 0.9832 - val_accuracy: 0.6532 - 21s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.97202 to 0.88426, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.9497 - accuracy: 0.6689 - val_loss: 0.8843 - val_accuracy: 0.6886 - 22s/epoch - 18ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.88426 to 0.87056, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.9224 - accuracy: 0.6779 - val_loss: 0.8706 - val_accuracy: 0.6953 - 23s/epoch - 18ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.87056
# 1250/1250 - 21s - loss: 0.8986 - accuracy: 0.6856 - val_loss: 0.8749 - val_accuracy: 0.6909 - 21s/epoch - 17ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.87056 to 0.82804, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8759 - accuracy: 0.6958 - val_loss: 0.8280 - val_accuracy: 0.7092 - 22s/epoch - 18ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.82804
# 1250/1250 - 22s - loss: 0.8522 - accuracy: 0.7070 - val_loss: 0.8308 - val_accuracy: 0.7092 - 22s/epoch - 17ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.82804 to 0.80904, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8380 - accuracy: 0.7082 - val_loss: 0.8090 - val_accuracy: 0.7221 - 23s/epoch - 18ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.80904 to 0.78531, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8215 - accuracy: 0.7148 - val_loss: 0.7853 - val_accuracy: 0.7255 - 23s/epoch - 18ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.78531 to 0.77493, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8022 - accuracy: 0.7217 - val_loss: 0.7749 - val_accuracy: 0.7309 - 23s/epoch - 18ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.77493
# 1250/1250 - 22s - loss: 0.7937 - accuracy: 0.7263 - val_loss: 0.7766 - val_accuracy: 0.7325 - 22s/epoch - 17ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.77493 to 0.75749, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7810 - accuracy: 0.7321 - val_loss: 0.7575 - val_accuracy: 0.7387 - 23s/epoch - 18ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.75749 to 0.75712, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7688 - accuracy: 0.7330 - val_loss: 0.7571 - val_accuracy: 0.7387 - 22s/epoch - 17ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.75712 to 0.75169, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7626 - accuracy: 0.7361 - val_loss: 0.7517 - val_accuracy: 0.7458 - 22s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.75169 to 0.73912, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7518 - accuracy: 0.7419 - val_loss: 0.7391 - val_accuracy: 0.7487 - 23s/epoch - 18ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.73912 to 0.72546, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7376 - accuracy: 0.7452 - val_loss: 0.7255 - val_accuracy: 0.7515 - 23s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.72546 to 0.72234, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7380 - accuracy: 0.7469 - val_loss: 0.7223 - val_accuracy: 0.7522 - 23s/epoch - 18ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.72234 to 0.71660, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7260 - accuracy: 0.7519 - val_loss: 0.7166 - val_accuracy: 0.7552 - 23s/epoch - 18ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.71660 to 0.71286, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7223 - accuracy: 0.7546 - val_loss: 0.7129 - val_accuracy: 0.7602 - 23s/epoch - 18ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.71286 to 0.71256, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7151 - accuracy: 0.7563 - val_loss: 0.7126 - val_accuracy: 0.7546 - 23s/epoch - 18ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.71256 to 0.70127, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7118 - accuracy: 0.7580 - val_loss: 0.7013 - val_accuracy: 0.7611 - 23s/epoch - 18ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.70127 to 0.69506, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7052 - accuracy: 0.7598 - val_loss: 0.6951 - val_accuracy: 0.7627 - 22s/epoch - 17ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.69506
# 1250/1250 - 22s - loss: 0.7007 - accuracy: 0.7614 - val_loss: 0.7083 - val_accuracy: 0.7620 - 22s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.69506
# 1250/1250 - 23s - loss: 0.7004 - accuracy: 0.7610 - val_loss: 0.7269 - val_accuracy: 0.7512 - 23s/epoch - 18ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.69506
# 1250/1250 - 22s - loss: 0.6899 - accuracy: 0.7653 - val_loss: 0.6985 - val_accuracy: 0.7613 - 22s/epoch - 17ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.69506
# 1250/1250 - 22s - loss: 0.6840 - accuracy: 0.7689 - val_loss: 0.6966 - val_accuracy: 0.7646 - 22s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.69506
# 1250/1250 - 23s - loss: 0.6812 - accuracy: 0.7670 - val_loss: 0.7066 - val_accuracy: 0.7576 - 23s/epoch - 18ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.69506
# 1250/1250 - 23s - loss: 0.6834 - accuracy: 0.7671 - val_loss: 0.7161 - val_accuracy: 0.7569 - 23s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.69506 to 0.69022, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6788 - accuracy: 0.7698 - val_loss: 0.6902 - val_accuracy: 0.7626 - 23s/epoch - 18ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.69022 to 0.68587, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6731 - accuracy: 0.7729 - val_loss: 0.6859 - val_accuracy: 0.7661 - 23s/epoch - 18ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.68587 to 0.68457, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6668 - accuracy: 0.7741 - val_loss: 0.6846 - val_accuracy: 0.7676 - 22s/epoch - 17ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.68457 to 0.68285, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6637 - accuracy: 0.7757 - val_loss: 0.6829 - val_accuracy: 0.7697 - 23s/epoch - 18ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.68285
# 1250/1250 - 22s - loss: 0.6599 - accuracy: 0.7771 - val_loss: 0.6922 - val_accuracy: 0.7668 - 22s/epoch - 17ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.68285
# 1250/1250 - 22s - loss: 0.6595 - accuracy: 0.7782 - val_loss: 0.6847 - val_accuracy: 0.7687 - 22s/epoch - 17ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.68285 to 0.66449, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6496 - accuracy: 0.7811 - val_loss: 0.6645 - val_accuracy: 0.7780 - 22s/epoch - 17ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.66449
# 1250/1250 - 23s - loss: 0.6558 - accuracy: 0.7789 - val_loss: 0.6857 - val_accuracy: 0.7683 - 23s/epoch - 18ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.66449
# 1250/1250 - 22s - loss: 0.6523 - accuracy: 0.7798 - val_loss: 0.6796 - val_accuracy: 0.7793 - 22s/epoch - 17ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.66449
# 1250/1250 - 22s - loss: 0.6467 - accuracy: 0.7820 - val_loss: 0.6772 - val_accuracy: 0.7698 - 22s/epoch - 17ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.66449
# 1250/1250 - 22s - loss: 0.6468 - accuracy: 0.7840 - val_loss: 0.6668 - val_accuracy: 0.7721 - 22s/epoch - 17ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.66449
# 1250/1250 - 23s - loss: 0.6378 - accuracy: 0.7839 - val_loss: 0.6709 - val_accuracy: 0.7740 - 23s/epoch - 18ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.66449 to 0.66429, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6364 - accuracy: 0.7851 - val_loss: 0.6643 - val_accuracy: 0.7744 - 22s/epoch - 17ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.66429
# 1250/1250 - 22s - loss: 0.6309 - accuracy: 0.7867 - val_loss: 0.6768 - val_accuracy: 0.7759 - 22s/epoch - 17ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.66429 to 0.65284, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6304 - accuracy: 0.7882 - val_loss: 0.6528 - val_accuracy: 0.7795 - 22s/epoch - 17ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.65284
# 1250/1250 - 22s - loss: 0.6343 - accuracy: 0.7877 - val_loss: 0.6583 - val_accuracy: 0.7778 - 22s/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.65284
# 1250/1250 - 23s - loss: 0.6268 - accuracy: 0.7880 - val_loss: 0.6581 - val_accuracy: 0.7753 - 23s/epoch - 18ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.65284 to 0.64957, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6329 - accuracy: 0.7866 - val_loss: 0.6496 - val_accuracy: 0.7808 - 23s/epoch - 18ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64957
# 1250/1250 - 22s - loss: 0.6229 - accuracy: 0.7898 - val_loss: 0.6708 - val_accuracy: 0.7796 - 22s/epoch - 17ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.64957
# 1250/1250 - 23s - loss: 0.6240 - accuracy: 0.7897 - val_loss: 0.6543 - val_accuracy: 0.7827 - 23s/epoch - 18ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.64957
# 1250/1250 - 23s - loss: 0.6269 - accuracy: 0.7905 - val_loss: 0.6684 - val_accuracy: 0.7801 - 23s/epoch - 18ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.64957
# 1250/1250 - 22s - loss: 0.6197 - accuracy: 0.7940 - val_loss: 0.6959 - val_accuracy: 0.7727 - 22s/epoch - 17ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.64957
# 1250/1250 - 22s - loss: 0.6144 - accuracy: 0.7953 - val_loss: 0.6732 - val_accuracy: 0.7747 - 22s/epoch - 18ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.64957
# 1250/1250 - 23s - loss: 0.6142 - accuracy: 0.7954 - val_loss: 0.7018 - val_accuracy: 0.7752 - 23s/epoch - 18ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.64957
# 1250/1250 - 22s - loss: 0.6161 - accuracy: 0.7956 - val_loss: 0.6575 - val_accuracy: 0.7826 - 22s/epoch - 17ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.64957
# 1250/1250 - 23s - loss: 0.6039 - accuracy: 0.7983 - val_loss: 0.6989 - val_accuracy: 0.7705 - 23s/epoch - 18ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.64957
# 1250/1250 - 22s - loss: 0.6137 - accuracy: 0.7948 - val_loss: 0.6637 - val_accuracy: 0.7793 - 22s/epoch - 17ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.64957 to 0.64676, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6136 - accuracy: 0.7973 - val_loss: 0.6468 - val_accuracy: 0.7849 - 22s/epoch - 17ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.64676
# 1250/1250 - 21s - loss: 0.6101 - accuracy: 0.7952 - val_loss: 0.6665 - val_accuracy: 0.7799 - 21s/epoch - 17ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.64676
# 1250/1250 - 22s - loss: 0.6042 - accuracy: 0.7990 - val_loss: 0.6690 - val_accuracy: 0.7806 - 22s/epoch - 17ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 0.64676 to 0.64451, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6031 - accuracy: 0.7997 - val_loss: 0.6445 - val_accuracy: 0.7886 - 22s/epoch - 17ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.6077 - accuracy: 0.7976 - val_loss: 0.6484 - val_accuracy: 0.7843 - 22s/epoch - 17ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.6025 - accuracy: 0.7996 - val_loss: 0.6605 - val_accuracy: 0.7841 - 22s/epoch - 17ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.6015 - accuracy: 0.7992 - val_loss: 0.6496 - val_accuracy: 0.7875 - 22s/epoch - 18ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.6029 - accuracy: 0.8012 - val_loss: 0.6500 - val_accuracy: 0.7879 - 22s/epoch - 17ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.6031 - accuracy: 0.7976 - val_loss: 0.6588 - val_accuracy: 0.7847 - 22s/epoch - 18ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.5993 - accuracy: 0.7990 - val_loss: 0.6574 - val_accuracy: 0.7843 - 22s/epoch - 18ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.64451
# 1250/1250 - 22s - loss: 0.5942 - accuracy: 0.8029 - val_loss: 0.6824 - val_accuracy: 0.7777 - 22s/epoch - 18ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.64451 to 0.64374, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.5899 - accuracy: 0.8050 - val_loss: 0.6437 - val_accuracy: 0.7901 - 22s/epoch - 18ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5995 - accuracy: 0.8026 - val_loss: 0.6451 - val_accuracy: 0.7914 - 22s/epoch - 17ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5978 - accuracy: 0.8017 - val_loss: 0.6483 - val_accuracy: 0.7902 - 22s/epoch - 18ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.64374
# 1250/1250 - 23s - loss: 0.5948 - accuracy: 0.8038 - val_loss: 0.6790 - val_accuracy: 0.7799 - 23s/epoch - 18ms/step
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.64374
# 1250/1250 - 23s - loss: 0.5910 - accuracy: 0.8024 - val_loss: 0.6513 - val_accuracy: 0.7864 - 23s/epoch - 18ms/step
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.64374
# 1250/1250 - 21s - loss: 0.5886 - accuracy: 0.8009 - val_loss: 0.6753 - val_accuracy: 0.7809 - 21s/epoch - 17ms/step
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5928 - accuracy: 0.8045 - val_loss: 0.6579 - val_accuracy: 0.7892 - 22s/epoch - 18ms/step
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5906 - accuracy: 0.8031 - val_loss: 0.6749 - val_accuracy: 0.7782 - 22s/epoch - 17ms/step
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5889 - accuracy: 0.8066 - val_loss: 0.6628 - val_accuracy: 0.7851 - 22s/epoch - 18ms/step
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5889 - accuracy: 0.8032 - val_loss: 0.6805 - val_accuracy: 0.7800 - 22s/epoch - 18ms/step
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.64374
# 1250/1250 - 22s - loss: 0.5874 - accuracy: 0.8048 - val_loss: 0.6521 - val_accuracy: 0.7825 - 22s/epoch - 18ms/step

# %%
best_model = load_moel(model_path)
best_model.evaluate(X_test, Y_test)

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
