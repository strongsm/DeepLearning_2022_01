# %% [markdown]
# # Cifar-100 이미지 분류 v2

# %% [markdown]
# - Cifar-100용 별도 모델
# - 32/64/128 Conv2D node 수
# - Adam() optimizer 사용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar100
(X_train, y_train), (X_test, y_test) = cifar100.load_data()

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'    
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
for i in range(40):
    plt.subplot(4,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
# X_train = X_train.astype(float) / 255. , X_train = X_train / 255. ==> 64bit 실수
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.1),
    Conv2D(128, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,193,636
# Trainable params: 1,193,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar100-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 3.97022, saving model to best-cifar100-v2.h5
# 1250/1250 - 18s - loss: 4.3413 - accuracy: 0.0404 - val_loss: 3.9702 - val_accuracy: 0.1053 - 18s/epoch - 15ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 3.97022 to 3.65452, saving model to best-cifar100-v2.h5
# 1250/1250 - 16s - loss: 3.9039 - accuracy: 0.1026 - val_loss: 3.6545 - val_accuracy: 0.1598 - 16s/epoch - 12ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 3.65452 to 3.47940, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.6730 - accuracy: 0.1389 - val_loss: 3.4794 - val_accuracy: 0.1913 - 15s/epoch - 12ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 3.47940 to 3.34035, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.5178 - accuracy: 0.1689 - val_loss: 3.3404 - val_accuracy: 0.2121 - 15s/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 3.34035 to 3.21101, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.3945 - accuracy: 0.1907 - val_loss: 3.2110 - val_accuracy: 0.2340 - 15s/epoch - 12ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 3.21101 to 3.10763, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 3.2848 - accuracy: 0.2112 - val_loss: 3.1076 - val_accuracy: 0.2521 - 14s/epoch - 11ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 3.10763 to 3.03832, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.1920 - accuracy: 0.2260 - val_loss: 3.0383 - val_accuracy: 0.2633 - 15s/epoch - 12ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 3.03832 to 2.94970, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.0972 - accuracy: 0.2435 - val_loss: 2.9497 - val_accuracy: 0.2808 - 15s/epoch - 12ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 2.94970 to 2.87321, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 3.0218 - accuracy: 0.2571 - val_loss: 2.8732 - val_accuracy: 0.2947 - 15s/epoch - 12ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 2.87321 to 2.84293, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.9500 - accuracy: 0.2714 - val_loss: 2.8429 - val_accuracy: 0.3020 - 14s/epoch - 11ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 2.84293 to 2.76677, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 2.8885 - accuracy: 0.2827 - val_loss: 2.7668 - val_accuracy: 0.3182 - 15s/epoch - 12ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 2.76677 to 2.73483, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.8205 - accuracy: 0.2955 - val_loss: 2.7348 - val_accuracy: 0.3254 - 14s/epoch - 11ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 2.73483 to 2.69623, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.7681 - accuracy: 0.3032 - val_loss: 2.6962 - val_accuracy: 0.3324 - 14s/epoch - 11ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 2.69623 to 2.67628, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.7219 - accuracy: 0.3152 - val_loss: 2.6763 - val_accuracy: 0.3379 - 14s/epoch - 11ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 2.67628 to 2.60466, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.6742 - accuracy: 0.3239 - val_loss: 2.6047 - val_accuracy: 0.3513 - 14s/epoch - 11ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 2.60466 to 2.57406, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 2.6210 - accuracy: 0.3354 - val_loss: 2.5741 - val_accuracy: 0.3588 - 14s/epoch - 11ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from
ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 2.19199 to 2.18753, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 1.8691 - accuracy: 0.4967 - val_loss: 2.1875 - val_accuracy: 0.4365 - 14s/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 2.18753
# 1250/1250 - 15s - loss: 1.8470 - accuracy: 0.4977 - val_loss: 2.1989 - val_accuracy: 0.4367 - 15s/epoch - 12ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 2.18753 to 2.16991, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 1.8229 - accuracy: 0.5037 - val_loss: 2.1699 - val_accuracy: 0.4403 - 14s/epoch - 11ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 2.16991 to 2.16919, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 1.8047 - accuracy: 0.5060 - val_loss: 2.1692 - val_accuracy: 0.4440 - 15s/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 2.16919 to 2.16243, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 1.7811 - accuracy: 0.5110 - val_loss: 2.1624 - val_accuracy: 0.4480 - 14s/epoch - 11ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 2.16243
# 1250/1250 - 14s - loss: 1.7583 - accuracy: 0.5186 - val_loss: 2.1651 - val_accuracy: 0.4461 - 14s/epoch - 11ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 2.16243
# 1250/1250 - 14s - loss: 1.7414 - accuracy: 0.5226 - val_loss: 2.1734 - val_accuracy: 0.4456 - 14s/epoch - 11ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 2.16243 to 2.15714, saving model to best-cifar100-v2.h5
# 1250/1250 - 14s - loss: 1.7200 - accuracy: 0.5242 - val_loss: 2.1571 - val_accuracy: 0.4489 - 14s/epoch - 11ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 2.15714 to 2.13645, saving model to best-cifar100-v2.h5
# 1250/1250 - 15s - loss: 1.7029 - accuracy: 0.5298 - val_loss: 2.1364 - val_accuracy: 0.4535 - 15s/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.6665 - accuracy: 0.5379 - val_loss: 2.1368 - val_accuracy: 0.4512 - 14s/epoch - 11ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.6545 - accuracy: 0.5420 - val_loss: 2.1368 - val_accuracy: 0.4526 - 14s/epoch - 11ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.6328 - accuracy: 0.5448 - val_loss: 2.1366 - val_accuracy: 0.4524 - 14s/epoch - 11ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 2.13645
# 1250/1250 - 15s - loss: 1.6217 - accuracy: 0.5482 - val_loss: 2.1375 - val_accuracy: 0.4548 - 15s/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 2.13645
# 1250/1250 - 15s - loss: 1.5873 - accuracy: 0.5560 - val_loss: 2.1428 - val_accuracy: 0.4534 - 15s/epoch - 12ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 2.13645
# 1250/1250 - 15s - loss: 1.5747 - accuracy: 0.5577 - val_loss: 2.1381 - val_accuracy: 0.4585 - 15s/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.5555 - accuracy: 0.5631 - val_loss: 2.1492 - val_accuracy: 0.4543 - 14s/epoch - 11ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.5385 - accuracy: 0.5659 - val_loss: 2.1412 - val_accuracy: 0.4538 - 14s/epoch - 11ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 2.13645
# 1250/1250 - 15s - loss: 1.5224 - accuracy: 0.5697 - val_loss: 2.1372 - val_accuracy: 0.4531 - 15s/epoch - 12ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 2.13645
# 1250/1250 - 14s - loss: 1.5013 - accuracy: 0.5773 - val_loss: 2.1485 - val_accuracy: 0.4566 - 14s/epoch - 11ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 2.1104 - accuracy: 0.4556
# [2.110421895980835, 0.45559999346733093]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
