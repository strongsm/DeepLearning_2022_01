# %% [markdown]
# # 고양이, 개 분류 - CNN v4
# - Dropout 추가
# - 이미지를 중앙에 배치
# - 각 이미지를 10개씩 부풀려 파일로 저장하고 이 파일로 학습

# %%
import cv2, os
import numpy as np
from tqdm.notebook import tqdm
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-01-23 09:26:01--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.193.128, 172.217.204.128, 172.217.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   175MB/s    in 0.4s
#
# 2022-01-23 09:26:02 (175 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip cats_and_dogs_filtered.zip > /dev/null

# %% [markdown]
# - 데이터 탐색

# %%
# 이미지를 축소/확대 및 센터링해서 이미지를 리턴하는 함수
IMAGE_SIZE = 150

def center_image(img, format='Image'):
    if format == 'Image':               # pillow image
        h, w, _ = np.array(img).shape
    else:                               # numpy array
        h, w = img.shape[:-1]
    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

    new_img = np.array(img.resize((width,height)))

    diff = abs(width - height)//2
    if width > height:
        final_img = new_img[:, diff:diff+IMAGE_SIZE, :]
    else:
        final_img = new_img[diff:diff+IMAGE_SIZE, :, :]

    return Image.fromarray(final_img) if format == 'Image' else final_img

# %%
CENTER_DIR = 'cats_and_dogs_centered'
train_dir = f'{CENTER_DIR}/train'
validation_dir = f'{CENTER_DIR}/validation'
train_cats_dir = f'{CENTER_DIR}/train/cats'
train_dogs_dir = f'{CENTER_DIR}/train/dogs'
validation_cats_dir = f'{CENTER_DIR}/validation/cats'
validation_dogs_dir = f'{CENTER_DIR}/validation/dogs'

# %%
if not os.path.exists(CENTER_DIR):
    os.mkdir(CENTER_DIR)
for dir in [train_dir,validation_dir,train_cats_dir,train_dogs_dir,validation_cats_dir,validation_dogs_dir]:
    os.mkdir(dir)

# %%
old_train_cats_dir = 'cats_and_dogs_filtered/train/cats'
old_train_dogs_dir = 'cats_and_dogs_filtered/train/dogs'
old_validation_cats_dir = 'cats_and_dogs_filtered/validation/cats'
old_validation_dogs_dir = 'cats_and_dogs_filtered/validation/dogs'

# %%
# cats_and_dogs_filtered -> image 축소/확대후 centering -> cats_and_dogs_centered
from glob import glob
for src_dir in [old_train_cats_dir,old_train_dogs_dir,old_validation_cats_dir,old_validation_dogs_dir]:
    dst_dir = src_dir.split('/')[1:]            # cats_and_dogs_filtered 제거
    dst_dir = '/'.join([CENTER_DIR] + dst_dir)  # CENTER_DIR 밑에 오는 디렉토리 지정
    for fname in glob(f'{src_dir}/*.jpg'):
        dst_fname = fname.split('/')[-1]    # 예를 들어, cat.475.jpg
        src_img = Image.open(fname)         # 사이즈가 제각각인 이미지
        dst_img = center_image(src_img)     # 150 x 150으로 centering된 이미지(pillow로 변경됨)
        dst_img.save(f'{dst_dir}/{dst_fname}')

# %% [markdown]
# - 이미지 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img

train_datagen = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for fname in tqdm(glob(f'{train_cats_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_cats_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
for fname in tqdm(glob(f'{train_dogs_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_dogs_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
len(os.listdir(train_cats_dir)), len(os.listdir(train_dogs_dir))
# Out:
# (10993, 10995)

# %%
plt.figure(figsize=(12,5))
cat_fnames = glob(f'{train_cats_dir}/*')
dog_fnames = glob(f'{train_dogs_dir}/*')
for i in range(5):
    img = Image.open(cat_fnames[i])
    plt.subplot(2,5,i+1)
    plt.imshow(img), plt.title(cat_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
    img = Image.open(dog_fnames[i])
    plt.subplot(2,5,i+1+5)
    plt.imshow(img), plt.title(dog_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# - 모델 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
validation_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 21988 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v4.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 모델 실행

# %%
hist = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    steps_per_epoch=100,        # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=50,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.69108, saving model to best-cat-dog-v4.h5
# 100/100 - 19s - loss: 0.9617 - accuracy: 0.5155 - val_loss: 0.6911 - val_accuracy: 0.5050 - 19s/epoch - 192ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.69108 to 0.67425, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.7012 - accuracy: 0.5635 - val_loss: 0.6743 - val_accuracy: 0.5600 - 4s/epoch - 43ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.67425 to 0.65786, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6464 - accuracy: 0.6280 - val_loss: 0.6579 - val_accuracy: 0.5810 - 4s/epoch - 42ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.65786 to 0.60689, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6232 - accuracy: 0.6710 - val_loss: 0.6069 - val_accuracy: 0.6830 - 4s/epoch - 41ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.60689 to 0.60145, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6049 - accuracy: 0.6895 - val_loss: 0.6014 - val_accuracy: 0.6580 - 4s/epoch - 42ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.60145
# 100/100 - 4s - loss: 0.5840 - accuracy: 0.7060 - val_loss: 0.6276 - val_accuracy: 0.6580 - 4s/epoch - 39ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.60145 to 0.59969, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6022 - accuracy: 0.6850 - val_loss: 0.5997 - val_accuracy: 0.6700 - 4s/epoch - 41ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.59969
# 100/100 - 4s - loss: 0.5845 - accuracy: 0.6900 - val_loss: 0.6624 - val_accuracy: 0.5970 - 4s/epoch - 41ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.59969 to 0.57491, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5748 - accuracy: 0.7195 - val_loss: 0.5749 - val_accuracy: 0.7050 - 4s/epoch - 41ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.57491
# 100/100 - 4s - loss: 0.5630 - accuracy: 0.7185 - val_loss: 0.5764 - val_accuracy: 0.6870 - 4s/epoch - 40ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.57491 to 0.56090, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5459 - accuracy: 0.7289 - val_loss: 0.5609 - val_accuracy: 0.7200 - 4s/epoch - 42ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.56090
# 100/100 - 4s - loss: 0.5695 - accuracy: 0.7200 - val_loss: 0.5641 - val_accuracy: 0.7120 - 4s/epoch - 39ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.56090
# 100/100 - 4s - loss: 0.5468 - accuracy: 0.7290 - val_loss: 0.5893 - val_accuracy: 0.6840 - 4s/epoch - 39ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.56090 to 0.55490, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5355 - accuracy: 0.7480 - val_loss: 0.5549 - val_accuracy: 0.7290 - 4s/epoch - 41ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.55490 to 0.53056, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4993 - accuracy: 0.7640 - val_loss: 0.5306 - val_accuracy: 0.7460 - 4s/epoch - 42ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.53056 to 0.53007, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5070 - accuracy: 0.7535 - val_loss: 0.5301 - val_accuracy: 0.7370 - 4s/epoch - 42ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.53007
# 100/100 - 4s - loss: 0.5058 - accuracy: 0.7596 - val_loss: 0.6418 - val_accuracy: 0.7110 - 4s/epoch - 40ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.53007 to 0.52310, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5219 - accuracy: 0.7475 - val_loss: 0.5231 - val_accuracy: 0.7540 - 4s/epoch - 41ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.52310
# 100/100 - 4s - loss: 0.5243 - accuracy: 0.7565 - val_loss: 0.5777 - val_accuracy: 0.7040 - 4s/epoch - 41ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.52310 to 0.51888, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5059 - accuracy: 0.7635 - val_loss: 0.5189 - val_accuracy: 0.7300 - 4s/epoch - 42ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.51888 to 0.51539, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5043 - accuracy: 0.7560 - val_loss: 0.5154 - val_accuracy: 0.7460 - 4s/epoch - 42ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.51539
# 100/100 - 4s - loss: 0.4779 - accuracy: 0.7770 - val_loss: 0.5328 - val_accuracy: 0.7370 - 4s/epoch - 40ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.51539 to 0.50008, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4789 - accuracy: 0.7750 - val_loss: 0.5001 - val_accuracy: 0.7670 - 4s/epoch - 41ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.50008
# 100/100 - 4s - loss: 0.4797 - accuracy: 0.7830 - val_loss: 0.6942 - val_accuracy: 0.7290 - 4s/epoch - 40ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.50008
# 100/100 - 4s - loss: 0.4921 - accuracy: 0.7695 - val_loss: 0.5116 - val_accuracy: 0.7440 - 4s/epoch - 39ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.50008 to 0.49248, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5188 - accuracy: 0.7570 - val_loss: 0.4925 - val_accuracy: 0.7580 - 4s/epoch - 42ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.49248 to 0.49117, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4850 - accuracy: 0.7721 - val_loss: 0.4912 - val_accuracy: 0.7640 - 4s/epoch - 42ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4887 - accuracy: 0.7730 - val_loss: 0.5151 - val_accuracy: 0.7510 - 4s/epoch - 41ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4873 - accuracy: 0.7675 - val_loss: 0.5156 - val_accuracy: 0.7520 - 4s/epoch - 41ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4763 - accuracy: 0.7770 - val_loss: 0.5197 - val_accuracy: 0.7430 - 4s/epoch - 41ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4592 - accuracy: 0.7930 - val_loss: 0.4977 - val_accuracy: 0.7680 - 4s/epoch - 41ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4674 - accuracy: 0.7860 - val_loss: 0.4951 - val_accuracy: 0.7610 - 4s/epoch - 41ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4518 - accuracy: 0.7933 - val_loss: 0.4948 - val_accuracy: 0.7560 - 4s/epoch - 42ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4785 - accuracy: 0.7680 - val_loss: 0.5026 - val_accuracy: 0.7550 - 4s/epoch - 42ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4730 - accuracy: 0.7820 - val_loss: 0.4951 - val_accuracy: 0.7550 - 4s/epoch - 41ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4418 - accuracy: 0.7955 - val_loss: 0.4916 - val_accuracy: 0.7770 - 4s/epoch - 41ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.49117
# 100/100 - 4s - loss: 0.4593 - accuracy: 0.7760 - val_loss: 0.5764 - val_accuracy: 0.7280 - 4s/epoch - 40ms/step

# %%
# centering 만 했을 경우: 0.6920
# centering과 augmentation을 했을 경우: 0.7900
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 테스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-ce9a9fed-1238-429c-8efe-6a77d4f5bcdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce9a9fed-1238-429c-8efe-6a77d4f5bcdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# Saving cocker-spaniel.jpg to cocker-spaniel.jpg
# Saving dog1.jpg to dog1.jpg
# Saving dog2.jpg to dog2.jpg

# %%
for fname in up.keys():
    img = Image.open(fname)
    img = center_image(img)
    classes = best_model.predict(np.array(img).reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")
# Out:
# 1.0000 cat.jpg is a dog
# 1.0000 cocker-spaniel.jpg is a dog
# 1.0000 dog1.jpg is a dog
# 0.0000 dog2.jpg is a cat

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
