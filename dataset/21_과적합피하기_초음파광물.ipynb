# %% [markdown]
# # 과적합 피하기 - 초음파 광물 데이터

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from google.colab import files
up = files.upload()
filename = list(up.keys())[0]
# Out:
#      <input type="file" id="files-3dc4ba9e-2d47-4748-a214-cbb21f8b9e49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dc4ba9e-2d47-4748-a214-cbb21f8b9e49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sonar.csv to sonar (2).csv

# %%
df = pd.read_csv(filename, header=None)
df.head(3)
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
#
# [3 rows x 61 columns]

# %%
np.unique(df.values[:,-1], return_counts=True)
# Out:
# (array(['M', 'R'], dtype=object), array([111,  97]))

# %%
# X data: scaling
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(df.iloc[:,:-1].values)

# %%
# Y data: label encoding
from sklearn.preprocessing import LabelEncoder
y_labeled = LabelEncoder().fit_transform(df.iloc[:,-1].values)

# %%
np.array([0.1, 0.2, 'R'])  # 타입이 str으로 바뀜
# Out:
# array(['0.1', '0.2', 'R'], dtype='<U32')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_labeled, stratify=y_labeled, test_size=0.2, random_state=seed
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((166, 60), (42, 60), (166,), (42,))

# %% [markdown]
# ### 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# - 1. 은닉층: 2개

# %%
model1 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4880
#
#  dense_1 (Dense)             (None, 12)                972
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h1 = model1.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model1.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3529 - accuracy: 0.9048
# [0.3528617322444916, 0.9047619104385376]

# %% [markdown]
# - 2. 은닉층: 4개

# %%
model2 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(30, activation='relu'),
    Dense(12, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                3904
#
#  dense_4 (Dense)             (None, 30)                1950
#
#  dense_5 (Dense)             (None, 12)                372
#
#  dense_6 (Dense)             (None, 4)                 52
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 6,283
# Trainable params: 6,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h2 = model2.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model2.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5415 - accuracy: 0.8095
# [0.5415384769439697, 0.8095238208770752]

# %% [markdown]
# - 3. 은닉층: 6개

# %%
model3 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(40, activation='relu'),
    Dense(28, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                3904
#
#  dense_9 (Dense)             (None, 40)                2600
#
#  dense_10 (Dense)            (None, 28)                1148
#
#  dense_11 (Dense)            (None, 16)                464
#
#  dense_12 (Dense)            (None, 8)                 136
#
#  dense_13 (Dense)            (None, 4)                 36
#
#  dense_14 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 8,293
# Trainable params: 8,293
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h3 = model3.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model3.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5902 - accuracy: 0.8333
# [0.5901774168014526, 0.8333333134651184]

# %% [markdown]
# - model1을 그대로 사용하는데, epoch 횟수를 늘린다.

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 80)                4880
#
#  dense_16 (Dense)            (None, 12)                972
#
#  dense_17 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(X_train, y_train, validation_split=0.2, epochs=1000, batch_size=50, verbose=0)
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6320 - accuracy: 0.8571
# [0.6319936513900757, 0.8571428656578064]

# %%
y_acc = hist.history['accuracy'][:200]
y_vloss = hist.history['val_loss'][:200]
xs = np.arange(1,len(y_acc)+1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# - 모델 저장 조건 설정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import os
if not os.path.exists('model'):
    os.mkdir('model')

# %%
model_path = 'model/sonar.h5'
checkpoint = ModelCheckpoint(
    model_path, monitor='val_loss', verbose=1, save_best_only=True
)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 80)                4880
#
#  dense_19 (Dense)            (None, 12)                972
#
#  dense_20 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2, 
    epochs=400, batch_size=50, verbose=0,
    callbacks=[checkpoint]
)
# Out:
# Epoch 00001: val_loss improved from inf to 0.72003, saving model to model/sonar.h5
#
# Epoch 00002: val_loss improved from 0.72003 to 0.66242, saving model to model/sonar.h5
#
# Epoch 00003: val_loss improved from 0.66242 to 0.61769, saving model to model/sonar.h5
#
# Epoch 00004: val_loss improved from 0.61769 to 0.58137, saving model to model/sonar.h5
#
# Epoch 00005: val_loss improved from 0.58137 to 0.54842, saving model to model/sonar.h5
#
# Epoch 00006: val_loss improved from 0.54842 to 0.51908, saving model to model/sonar.h5
#
# Epoch 00007: val_loss improved from 0.51908 to 0.49327, saving model to model/sonar.h5
#
# Epoch 00008: val_loss improved from 0.49327 to 0.47123, saving model to model/sonar.h5
#
# Epoch 00009: val_loss improved from 0.47123 to 0.45347, saving model to model/sonar.h5
#
# Epoch 00010: val_loss improved from 0.45347 to 0.43932, saving model to model/sonar.h5
#
# Epoch 00011: val_loss improved from 0.43932 to 0.42671, saving model to model/sonar.h5
#
# Epoch 00012: val_loss improved from 0.42671 to 0.41696, saving model to model/sonar.h5
#
# Epoch 00013: val_loss improved from 0.41696 to 0.40747, saving model to model/sonar.h5
#
# Epoch 00014: val_loss improved from 0.40747 to 0.39809, saving model to model/sonar.h5
#
# Epoch 00015: val_loss improved from 0.39809 to 0.39017, saving model to model/sonar.h5
#
# Epoch 00016: val_loss improved from 0.39017 to 0.38307, saving model to model/sonar.h5
#
# Epoch 00017: val_loss improved from 0.38307 to 0.37694, saving model to model/sonar.h5
#
# Epoch 00018: val_loss improved from 0.37694 to 0.37129, saving model to model/sonar.h5
#
# Epoch 00019: val_loss improved from 0.37129 to 0.36771, saving model to model/sonar.h5
#
# Epoch 00020: val_loss improved from 0.36771 to 0.36312, saving model to model/sonar.h5
#
# Epoch 00021: val_loss improved from 0.36312 to 0.35827, saving model to model/sonar.h5
#
# Epoch 00022: val_loss improved from 0.35827 to 0.35452, saving model to model/sonar.h5
#
# Epoch 00023: val_loss improved from 0.35452 to 0.35101, saving model to model/sonar.h5
#
# Epoch 00024: val_loss improved from 0.35101 to 0.34818, saving model to model/sonar.h5
#
# Epoch 00025: val_loss improved from 0.34818 to 0.34491, saving model to model/sonar.h5
#
# Epoch 00026: val_loss improved from 0.34491 to 0.34165, saving model to model/sonar.h5
#
# Epoch 00027: val_loss did not improve from 0.34165
#
# Epoch 00028: val_loss improved from 0.34165 to 0.34107, saving model to model/sonar.h5
#
# Epoch 00029: val_loss improved from 0.34107 to 0.33786, saving model to model/sonar.h5
#
# Epoch 00030: val_loss improved from 0.33786 to 0.33579, saving model to model/sonar.h5
#
# Epoch 00031: val_loss improved from 0.33579 to 0.33190, saving model to model/sonar.h5
#
# Epoch 00032: val_loss improved from 0.33190 to 0.33093, saving model to model/sonar.h5
#
# Epoch 00033: val_loss improved from 0.33093 to 0.33046, saving model to model/sonar.h5
#
# Epoch 00034: val_loss improved from 0.33046 to 0.33027, saving model to model/sonar.h5
#
# Epoch 00035: val_loss improved from 0.33027 to 0.32879, saving model to model/sonar.h5
#
# Epoch 00036: val_loss improved from 0.32879 to 0.32872, saving model to model/sonar.h5
#
# Epoch 00037: val_loss improved from 0.32872 to 0.32562, saving model to model/sonar.h5
#
# Epoch 00038: val_loss improved from 0.32562 to 0.32285, saving model to model/sonar.h5
#
# Epoch 00039: val_loss improved from 0.32285 to 0.32007, saving model to model/sonar.h5
#
# Epoch 00040: val_loss improved from 0.32007 to 0.31857, saving model to model/sonar.h5
#
# Epoch 00041: val_loss improved from 0.31857 to 0.31725, saving model to model/sonar.h5
#
# Epoch 00042: val_loss improved from 0.31725 to 0.31652, saving model to model/sonar.h5
#
# Epoch 00043: val_loss improved from 0.31652 to 0.31436, saving model to model/sonar.h5
#
# Epoch 00044: val_loss improved from 0.31436 to 0.31206, saving model to model/sonar.h5
#
# Epoch 00045: val_loss improved from 0.31206 to 0.31112, saving model to model/sonar.h5
#
# Epoch 00046: val_loss improved from 0.31112 to 0.31006, saving model to model/sonar.h5
#
# Epoch 00047: val_loss improved from 0.31006 to 0.30987, saving model to model/sonar.h5
#
# Epoch 00048: val_loss did not improve from 0.30987
#
# Epoch 00049: val_loss improved from 0.30987 to 0.30948, saving model to model/sonar.h5
#
# Epoch 00050: val_loss improved from 0.30948 to 0.30826, saving model to model/sonar.h5
#
# Epoch 00051: val_loss did not improve from 0.30826
#
# Epoch 00052: val_loss improved from 0.30826 to 0.30712, saving model to model/sonar.h5
#
# Epoch 00053: val_loss did not improve from 0.30712
#
# Epoch 00054: val_loss improved from 0.30712 to 0.30704, saving model to model/sonar.h5
#
# Epoch 00055: val_loss improved from 0.30704 to 0.30687, saving model to model/sonar.h5
#
# Epoch 00056: val_loss improved from 0.30687 to 0.30656, saving model to model/sonar.h5
#
# Epoch 00057: val_loss improved from 0.30656 to 0.30635, saving model to model/sonar.h5
#
# Epoch 00058: val_loss improved from 0.30635 to 0.30618, saving model to model/sonar.h5
#
# Epoch 00059: val_loss improved from 0.30618 to 0.30414, saving model to model/sonar.h5
#
# Epoch 00060: val_loss improved from 0.30414 to 0.30319, saving model to model/sonar.h5
#
# Epoch 00061: val_loss improved from 0.30319 to 0.30255, saving model to model/sonar.h5
#
# Epoch 00062: val_loss improved from 0.30255 to 0.29985, saving model to model/sonar.h5
#
# Epoch 00063: val_loss improved from 0.29985 to 0.29840, saving model to model/sonar.h5
#
# Epoch 00064: val_loss improved from 0.29840 to 0.29626, saving model to model/sonar.h5
#
# Epoch 00065: val_loss improved from 0.29626 to 0.29459, saving model to model/sonar.h5
#
# Epoch 00066: val_loss improved from 0.29459 to 0.29406, saving model to model/sonar.h5
#
# Epoch 00067: val_loss did not improve from 0.29406
#
# Epoch 00068: val_loss did not improve from 0.29406
#
# Epoch 00069: val_loss did not improve from 0.29406
#
# Epoch 00070: val_loss improved from 0.29406 to 0.29318, saving model to model/sonar.h5
#
# Epoch 00071: val_loss improved from 0.29318 to 0.29198, saving model to model/sonar.h5
#
# Epoch 00072: val_loss did not improve from 0.29198
#
# Epoch 00073: val_loss did not improve from 0.29198
#
# Epoch 00074: val_loss did not improve from 0.29198
#
# Epoch 00075: val_loss did not improve from 0.29198
#
# Epoch 00076: val_loss did not improve from 0.29198
#
# Epoch 00077: val_loss did not improve from 0.29198
#
# Epoch 00078: val_loss did not improve from 0.29198
#
# Epoch 00079: val_loss did not improve from 0.29198
#
# Epoch 00080: val_loss did not improve from 0.29198
#
# Epoch 00081: val_loss did not improve from 0.29198
#
# Epoch 00082: val_loss did not improve from 0.29198
#
# Epoch 00083: val_loss did not improve from 0.29198
#
# Epoch 00084: val_loss did not improve from 0.29198
#
# Epoch 00085: val_loss did not improve from 0.29198
#
# Epoch 00086: val_loss did not improve from 0.29198
#
# Epoch 00087: val_loss did not improve from 0.29198
#
# Epoch 00088: val_loss did not improve from 0.29198
#
# Epoch 00089: val_loss did not improve from 0.29198
#
# Epoch 00090: val_loss did not improve from 0.29198
#
# Epoch 00091: val_loss did not improve from 0.29198
#
# Epoch 00092: val_loss did not improve from 0.29198
#
# Epoch 00093: val_loss did not improve from 0.29198
#
# Epoch 00094: val_loss did not improve from 0.29198
#
# Epoch 00095: val_loss did not improve from 0.29198
#
# Epoch 00096: val_loss did not improve from 0.29198
#
# Epoch 00097: val_loss did not improve from 0.29198
#
# Epoch 00098: val_loss did not improve from 0.29198
#
# Epoch 00099: val_loss did not improve from 0.29198
#
# Epoch 00100: val_loss did not improve from 0.29198
#
# Epoch 00101: val_loss did not improve from 0.29198
#
# Epoch 00102: val_loss did not improve from 0.29198
#
# Epoch 00103: val_loss did not improve from 0.29198
#
# Epoch 00104: val_loss did not improve from 0.29198
#
# Epoch 00105: val_loss did not improve from 0.29198
#
# Epoch 00106: val_loss did not improve from 0.29198
#
# Epoch 00107: val_loss did not improve from 0.29198
#
# Epoch 00108: val_loss did not improve from 0.29198
#
# Epoch 00109: val_loss did not improve from 0.29198
#
# Epoch 00110: val_loss did not improve from 0.29198
#
# Epoch 00111: val_loss did not improve from 0.29198
#
# Epoch 00112: val_loss did not improve from 0.29198
#
# Epoch 00113: val_loss did not improve from 0.29198
#
# Epoch 00114: val_loss did not improve from 0.29198
#
# Epoch 00115: val_loss did not improve from 0.29198
#
# Epoch 00116: val_loss did not improve from 0.29198
#
# Epoch 00117: val_loss did not improve from 0.29198
#
# Epoch 00118: val_loss did not improve from 0.29198
#
# Epoch 00119: val_loss did not improve from 0.29198
#
# Epoch 00120: val_loss did not improve from 0.29198
#
# Epoch 00121: val_loss did not improve from 0.29198
#
# Epoch 00122: val_loss did not improve from 0.29198
#
# Epoch 00123: val_loss did not improve from 0.29198
#
# Epoch 00124: val_loss did not improve from 0.29198
#
# Epoch 00125: val_loss did not improve from 0.29198
#
# Epoch 00126: val_loss did not improve from 0.29198
#
# Epoch 00127: val_loss did not improve from 0.29198
#
# Epoch 00128: val_loss did not improve from 0.29198
#
# Epoch 00129: val_loss did not improve from 0.29198
#
# Epoch 00130: val_loss did not improve from 0.29198
#
# Epoch 00131: val_loss did not improve from 0.29198
#
# Epoch 00132: val_loss did not improve from 0.29198
#
# Epoch 00133: val_loss did not improve from 0.29198
#
# Epoch 00134: val_loss did not improve from 0.29198
#
# Epoch 00135: val_loss did not improve from 0.29198
#
# Epoch 00136: val_loss did not improve from 0.29198
#
# Epoch 00137: val_loss did not improve from 0.29198
#
# Epoch 00138: val_loss did not improve from 0.29198
#
# Epoch 00139: val_loss did not improve from 0.29198
#
# Epoch 00140: val_loss did not improve from 0.29198
#
# Epoch 00141: val_loss did not improve from 0.29198
#
# Epoch 00142: val_loss did not improve from 0.29198
#
# Epoch 00143: val_loss did not improve from 0.29198
#
# Epoch 00144: val_loss did not improve from 0.29198
#
# Epoch 00145: val_loss did not improve from 0.29198
#
# Epoch 00146: val_loss did not improve from 0.29198
#
# Epoch 00147: val_loss did not improve from 0.29198
#
# Epoch 00148: val_loss did not improve from 0.29198
#
# Epoch 00149: val_loss did not improve from 0.29198
#
# Epoch 00150: val_loss did not improve from 0.29198
#
# Epoch 00151: val_loss did not improve from 0.29198
#
# Epoch 00152: val_loss did not improve from 0.29198
#
# Epoch 00153: val_loss did not improve from 0.29198
#
# Epoch 00154: val_loss did not improve from 0.29198
#
# Epoch 00155: val_loss did not improve from 0.29198
#
# Epoch 00156: val_loss did not improve from 0.29198
#
# Epoch 00157: val_loss did not improve from 0.29198
#
# Epoch 00158: val_loss did not improve from 0.29198
#
# Epoch 00159: val_loss did not improve from 0.29198
#
# Epoch 00160: val_loss did not improve from 0.29198
#
# Epoch 00161: val_loss did not improve from 0.29198
#
# Epoch 00162: val_loss did not improve from 0.29198
#
# Epoch 00163: val_loss did not improve from 0.29198
#
# Epoch 00164: val_loss did not improve from 0.29198
#
# Epoch 00165: val_loss did not improve from 0.29198
#
# Epoch 00166: val_loss did not improve from 0.29198
#
# Epoch 00167: val_loss did not improve from 0.29198
#
# Epoch 00168: val_loss did not improve from 0.29198
#
# Epoch 00169: val_loss did not improve from 0.29198
#
# Epoch 00170: val_loss did not improve from 0.29198
#
# Epoch 00171: val_loss did not improve from 0.29198
#
# Epoch 00172: val_loss did not improve from 0.29198
#
# Epoch 00173: val_loss did not improve from 0.29198
#
# Epoch 00174: val_loss did not improve from 0.29198
#
# Epoch 00175: val_loss did not improve from 0.29198
#
# Epoch 00176: val_loss did not improve from 0.29198
#
# Epoch 00177: val_loss did not improve from 0.29198
#
# Epoch 00178: val_loss did not improve from 0.29198
#
# Epoch 00179: val_loss did not improve from 0.29198
#
# Epoch 00180: val_loss did not improve from 0.29198
#
# Epoch 00181: val_loss did not improve from 0.29198
#
# Epoch 00182: val_loss did not improve from 0.29198
#
# Epoch 00183: val_loss did not improve from 0.29198
#
# Epoch 00184: val_loss did not improve from 0.29198
#
# Epoch 00185: val_loss did not improve from 0.29198
#
# Epoch 00186: val_loss did not improve from 0.29198
#
# Epoch 00187: val_loss did not improve from 0.29198
#
# Epoch 00188: val_loss did not improve from 0.29198
#
# Epoch 00189: val_loss did not improve from 0.29198
#
# Epoch 00190: val_loss did not improve from 0.29198
#
# Epoch 00191: val_loss did not improve from 0.29198
#
# Epoch 00192: val_loss did not improve from 0.29198
#
# Epoch 00193: val_loss did not improve from 0.29198
#
# Epoch 00194: val_loss did not improve from 0.29198
#
# Epoch 00195: val_loss did not improve from 0.29198
#
# Epoch 00196: val_loss did not improve from 0.29198
#
# Epoch 00197: val_loss did not improve from 0.29198
#
# Epoch 00198: val_loss did not improve from 0.29198
#
# Epoch 00199: val_loss did not improve from 0.29198
#
# Epoch 00200: val_loss did not improve from 0.29198
#
# Epoch 00201: val_loss did not improve from 0.29198
#
# Epoch 00202: val_loss did not improve from 0.29198
#
# Epoch 00203: val_loss did not improve from 0.29198
#
# Epoch 00204: val_loss did not improve from 0.29198
#
# Epoch 00205: val_loss did not improve from 0.29198
#
# Epoch 00206: val_loss did not improve from 0.29198
#
# Epoch 00207: val_loss did not improve from 0.29198
#
# Epoch 00208: val_loss did not improve from 0.29198
#
# Epoch 00209: val_loss did not improve from 0.29198
#
# Epoch 00210: val_loss did not improve from 0.29198
#
# Epoch 00211: val_loss did not improve from 0.29198
#
# Epoch 00212: val_loss did not improve from 0.29198
#
# Epoch 00213: val_loss did not improve from 0.29198
#
# Epoch 00214: val_loss did not improve from 0.29198
#
# Epoch 00215: val_loss did not improve from 0.29198
#
# Epoch 00216: val_loss did not improve from 0.29198
#
# Epoch 00217: val_loss did not improve from 0.29198
#
# Epoch 00218: val_loss did not improve from 0.29198
#
# Epoch 00219: val_loss did not improve from 0.29198
#
# Epoch 00220: val_loss did not improve from 0.29198
#
# Epoch 00221: val_loss did not improve from 0.29198
#
# Epoch 00222: val_loss did not improve from 0.29198
#
# Epoch 00223: val_loss did not improve from 0.29198
#
# Epoch 00224: val_loss did not improve from 0.29198
#
# Epoch 00225: val_loss did not improve from 0.29198
#
# Epoch 00226: val_loss did not improve from 0.29198
#
# Epoch 00227: val_loss did not improve from 0.29198
#
# Epoch 00228: val_loss did not improve from 0.29198
#
# Epoch 00229: val_loss did not improve from 0.29198
#
# Epoch 00230: val_loss did not improve from 0.29198
#
# Epoch 00231: val_loss did not improve from 0.29198
#
# Epoch 00232: val_loss did not improve from 0.29198
#
# Epoch 00233: val_loss did not improve from 0.29198
#
# Epoch 00234: val_loss did not improve from 0.29198
#
# Epoch 00235: val_loss did not improve from 0.29198
#
# Epoch 00236: val_loss did not improve from 0.29198
#
# Epoch 00237: val_loss did not improve from 0.29198
#
# Epoch 00238: val_loss did not improve from 0.29198
#
# Epoch 00239: val_loss did not improve from 0.29198
#
# Epoch 00240: val_loss did not improve from 0.29198
#
# Epoch 00241: val_loss did not improve from 0.29198
#
# Epoch 00242: val_loss did not improve from 0.29198
#
# Epoch 00243: val_loss did not improve from 0.29198
#
# Epoch 00244: val_loss did not improve from 0.29198
#
# Epoch 00245: val_loss did not improve from 0.29198
#
# Epoch 00246: val_loss did not improve from 0.29198
#
# Epoch 00247: val_loss did not improve from 0.29198
#
# Epoch 00248: val_loss did not improve from 0.29198
#
# Epoch 00249: val_loss did not improve from 0.29198
#
# Epoch 00250: val_loss did not improve from 0.29198
#
# Epoch 00251: val_loss did not improve from 0.29198
#
# Epoch 00252: val_loss did not improve from 0.29198
#
# Epoch 00253: val_loss did not improve from 0.29198
#
# Epoch 00254: val_loss did not improve from 0.29198
#
# Epoch 00255: val_loss did not improve from 0.29198
#
# Epoch 00256: val_loss did not improve from 0.29198
#
# Epoch 00257: val_loss did not improve from 0.29198
#
# Epoch 00258: val_loss did not improve from 0.29198
#
# Epoch 00259: val_loss did not improve from 0.29198
#
# Epoch 00260: val_loss did not improve from 0.29198
#
# Epoch 00261: val_loss did not improve from 0.29198
#
# Epoch 00262: val_loss did not improve from 0.29198
#
# Epoch 00263: val_loss did not improve from 0.29198
#
# Epoch 00264: val_loss did not improve from 0.29198
#
# Epoch 00265: val_loss did not improve from 0.29198
#
# Epoch 00266: val_loss did not improve from 0.29198
#
# Epoch 00267: val_loss did not improve from 0.29198
#
# Epoch 00268: val_loss did not improve from 0.29198
#
# Epoch 00269: val_loss did not improve from 0.29198
#
# Epoch 00270: val_loss did not improve from 0.29198
#
# Epoch 00271: val_loss did not improve from 0.29198
#
# Epoch 00272: val_loss did not improve from 0.29198
#
# Epoch 00273: val_loss did not improve from 0.29198
#
# Epoch 00274: val_loss did not improve from 0.29198
#
# Epoch 00275: val_loss did not improve from 0.29198
#
# Epoch 00276: val_loss did not improve from 0.29198
#
# Epoch 00277: val_loss did not improve from 0.29198
#
# Epoch 00278: val_loss did not improve from 0.29198
#
# Epoch 00279: val_loss did not improve from 0.29198
#
# Epoch 00280: val_loss did not improve from 0.29198
#
# Epoch 00281: val_loss did not improve from 0.29198
#
# Epoch 00282: val_loss did not improve from 0.29198
#
# Epoch 00283: val_loss did not improve from 0.29198
#
# Epoch 00284: val_loss did not improve from 0.29198
#
# Epoch 00285: val_loss did not improve from 0.29198
#
# Epoch 00286: val_loss did not improve from 0.29198
#
# Epoch 00287: val_loss did not improve from 0.29198
#
# Epoch 00288: val_loss did not improve from 0.29198
#
# Epoch 00289: val_loss did not improve from 0.29198
#
# Epoch 00290: val_loss did not improve from 0.29198
#
# Epoch 00291: val_loss did not improve from 0.29198
#
# Epoch 00292: val_loss did not improve from 0.29198
#
# Epoch 00293: val_loss did not improve from 0.29198
#
# Epoch 00294: val_loss did not improve from 0.29198
#
# Epoch 00295: val_loss did not improve from 0.29198
#
# Epoch 00296: val_loss did not improve from 0.29198
#
# Epoch 00297: val_loss did not improve from 0.29198
#
# Epoch 00298: val_loss did not improve from 0.29198
#
# Epoch 00299: val_loss did not improve from 0.29198
#
# Epoch 00300: val_loss did not improve from 0.29198
#
# Epoch 00301: val_loss did not improve from 0.29198
#
# Epoch 00302: val_loss did not improve from 0.29198
#
# Epoch 00303: val_loss did not improve from 0.29198
#
# Epoch 00304: val_loss did not improve from 0.29198
#
# Epoch 00305: val_loss did not improve from 0.29198
#
# Epoch 00306: val_loss did not improve from 0.29198
#
# Epoch 00307: val_loss did not improve from 0.29198
#
# Epoch 00308: val_loss did not improve from 0.29198
#
# Epoch 00309: val_loss did not improve from 0.29198
#
# Epoch 00310: val_loss did not improve from 0.29198
#
# Epoch 00311: val_loss did not improve from 0.29198
#
# Epoch 00312: val_loss did not improve from 0.29198
#
# Epoch 00313: val_loss did not improve from 0.29198
#
# Epoch 00314: val_loss did not improve from 0.29198
#
# Epoch 00315: val_loss did not improve from 0.29198
#
# Epoch 00316: val_loss did not improve from 0.29198
#
# Epoch 00317: val_loss did not improve from 0.29198
#
# Epoch 00318: val_loss did not improve from 0.29198
#
# Epoch 00319: val_loss did not improve from 0.29198
#
# Epoch 00320: val_loss did not improve from 0.29198
#
# Epoch 00321: val_loss did not improve from 0.29198
#
# Epoch 00322: val_loss did not improve from 0.29198
#
# Epoch 00323: val_loss did not improve from 0.29198
#
# Epoch 00324: val_loss did not improve from 0.29198
#
# Epoch 00325: val_loss did not improve from 0.29198
#
# Epoch 00326: val_loss did not improve from 0.29198
#
# Epoch 00327: val_loss did not improve from 0.29198
#
# Epoch 00328: val_loss did not improve from 0.29198
#
# Epoch 00329: val_loss did not improve from 0.29198
#
# Epoch 00330: val_loss did not improve from 0.29198
#
# Epoch 00331: val_loss did not improve from 0.29198
#
# Epoch 00332: val_loss did not improve from 0.29198
#
# Epoch 00333: val_loss did not improve from 0.29198
#
# Epoch 00334: val_loss did not improve from 0.29198
#
# Epoch 00335: val_loss did not improve from 0.29198
#
# Epoch 00336: val_loss did not improve from 0.29198
#
# Epoch 00337: val_loss did not improve from 0.29198
#
# Epoch 00338: val_loss did not improve from 0.29198
#
# Epoch 00339: val_loss did not improve from 0.29198
#
# Epoch 00340: val_loss did not improve from 0.29198
#
# Epoch 00341: val_loss did not improve from 0.29198
#
# Epoch 00342: val_loss did not improve from 0.29198
#
# Epoch 00343: val_loss did not improve from 0.29198
#
# Epoch 00344: val_loss did not improve from 0.29198
#
# Epoch 00345: val_loss did not improve from 0.29198
#
# Epoch 00346: val_loss did not improve from 0.29198
#
# Epoch 00347: val_loss did not improve from 0.29198
#
# Epoch 00348: val_loss did not improve from 0.29198
#
# Epoch 00349: val_loss did not improve from 0.29198
#
# Epoch 00350: val_loss did not improve from 0.29198
#
# Epoch 00351: val_loss did not improve from 0.29198
#
# Epoch 00352: val_loss did not improve from 0.29198
#
# Epoch 00353: val_loss did not improve from 0.29198
#
# Epoch 00354: val_loss did not improve from 0.29198
#
# Epoch 00355: val_loss did not improve from 0.29198
#
# Epoch 00356: val_loss did not improve from 0.29198
#
# Epoch 00357: val_loss did not improve from 0.29198
#
# Epoch 00358: val_loss did not improve from 0.29198
#
# Epoch 00359: val_loss did not improve from 0.29198
#
# Epoch 00360: val_loss did not improve from 0.29198
#
# Epoch 00361: val_loss did not improve from 0.29198
#
# Epoch 00362: val_loss did not improve from 0.29198
#
# Epoch 00363: val_loss did not improve from 0.29198
#
# Epoch 00364: val_loss did not improve from 0.29198
#
# Epoch 00365: val_loss did not improve from 0.29198
#
# Epoch 00366: val_loss did not improve from 0.29198
#
# Epoch 00367: val_loss did not improve from 0.29198
#
# Epoch 00368: val_loss did not improve from 0.29198
#
# Epoch 00369: val_loss did not improve from 0.29198
#
# Epoch 00370: val_loss did not improve from 0.29198
#
# Epoch 00371: val_loss did not improve from 0.29198
#
# Epoch 00372: val_loss did not improve from 0.29198
#
# Epoch 00373: val_loss did not improve from 0.29198
#
# Epoch 00374: val_loss did not improve from 0.29198
#
# Epoch 00375: val_loss did not improve from 0.29198
#
# Epoch 00376: val_loss did not improve from 0.29198
#
# Epoch 00377: val_loss did not improve from 0.29198
#
# Epoch 00378: val_loss did not improve from 0.29198
#
# Epoch 00379: val_loss did not improve from 0.29198
#
# Epoch 00380: val_loss did not improve from 0.29198
#
# Epoch 00381: val_loss did not improve from 0.29198
#
# Epoch 00382: val_loss did not improve from 0.29198
#
# Epoch 00383: val_loss did not improve from 0.29198
#
# Epoch 00384: val_loss did not improve from 0.29198
#
# Epoch 00385: val_loss did not improve from 0.29198
#
# Epoch 00386: val_loss did not improve from 0.29198
#
# Epoch 00387: val_loss did not improve from 0.29198
#
# Epoch 00388: val_loss did not improve from 0.29198
#
# Epoch 00389: val_loss did not improve from 0.29198
#
# Epoch 00390: val_loss did not improve from 0.29198
#
# Epoch 00391: val_loss did not improve from 0.29198
#
# Epoch 00392: val_loss did not improve from 0.29198
#
# Epoch 00393: val_loss did not improve from 0.29198
#
# Epoch 00394: val_loss did not improve from 0.29198
#
# Epoch 00395: val_loss did not improve from 0.29198
#
# Epoch 00396: val_loss did not improve from 0.29198
#
# Epoch 00397: val_loss did not improve from 0.29198
#
# Epoch 00398: val_loss did not improve from 0.29198
#
# Epoch 00399: val_loss did not improve from 0.29198
#
# Epoch 00400: val_loss did not improve from 0.29198

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3980 - accuracy: 0.7857
# [0.3980017304420471, 0.7857142686843872]

# %% [markdown]
# - 조기 종류시점 설정

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=30)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 80)                4880
#
#  dense_22 (Dense)            (None, 12)                972
#
#  dense_23 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2, 
    epochs=400, batch_size=50, verbose=1,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/400
# 1/3 [=========>....................] - ETA: 1s - loss: 0.7483 - accuracy: 0.5600
# Epoch 00001: val_loss did not improve from 0.29198
# 3/3 [==============================] - 1s 82ms/step - loss: 0.6912 - accuracy: 0.5985 - val_loss: 0.6417 - val_accuracy: 0.7647
# Epoch 2/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6430 - accuracy: 0.6600
# Epoch 00002: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6252 - accuracy: 0.6894 - val_loss: 0.6079 - val_accuracy: 0.7647
# Epoch 3/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5551 - accuracy: 0.8000
# Epoch 00003: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5818 - accuracy: 0.7424 - val_loss: 0.5741 - val_accuracy: 0.7647
# Epoch 4/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5898 - accuracy: 0.7200
# Epoch 00004: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5464 - accuracy: 0.8106 - val_loss: 0.5431 - val_accuracy: 0.7353
# Epoch 5/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5666 - accuracy: 0.7400
# Epoch 00005: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5142 - accuracy: 0.8258 - val_loss: 0.5171 - val_accuracy: 0.8235
# Epoch 6/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4969 - accuracy: 0.8000
# Epoch 00006: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4861 - accuracy: 0.8561 - val_loss: 0.4928 - val_accuracy: 0.8529
# Epoch 7/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4629 - accuracy: 0.8600
# Epoch 00007: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4581 - accuracy: 0.8788 - val_loss: 0.4708 - val_accuracy: 0.8529
# Epoch 8/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4544 - accuracy: 0.9000
# Epoch 00008: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4315 - accuracy: 0.8788 - val_loss: 0.4498 - val_accuracy: 0.9118
# Epoch 9/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4132 - accuracy: 0.8800
# Epoch 00009: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4043 - accuracy: 0.8788 - val_loss: 0.4318 - val_accuracy: 0.8824
# Epoch 10/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4172 - accuracy: 0.8400
# Epoch 00010: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3801 - accuracy: 0.9015 - val_loss: 0.4157 - val_accuracy: 0.8824
# Epoch 11/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3476 - accuracy: 0.9000
# Epoch 00011: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3577 - accuracy: 0.9091 - val_loss: 0.4009 - val_accuracy: 0.8824
# Epoch 12/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4073 - accuracy: 0.9000
# Epoch 00012: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3367 - accuracy: 0.9242 - val_loss: 0.3883 - val_accuracy: 0.8529
# Epoch 13/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3523 - accuracy: 0.8800
# Epoch 00013: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3181 - accuracy: 0.9242 - val_loss: 0.3764 - val_accuracy: 0.8529
# Epoch 14/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3200 - accuracy: 0.9000
# Epoch 00014: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3002 - accuracy: 0.9242 - val_loss: 0.3645 - val_accuracy: 0.8529
# Epoch 15/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3325 - accuracy: 0.8800
# Epoch 00015: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2831 - accuracy: 0.9318 - val_loss: 0.3535 - val_accuracy: 0.8529
# Epoch 16/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2902 - accuracy: 0.9200
# Epoch 00016: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2664 - accuracy: 0.9394 - val_loss: 0.3431 - val_accuracy: 0.8529
# Epoch 17/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3045 - accuracy: 0.9200
# Epoch 00017: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2516 - accuracy: 0.9394 - val_loss: 0.3334 - val_accuracy: 0.8529
# Epoch 18/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2980 - accuracy: 0.9000
# Epoch 00018: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2370 - accuracy: 0.9394 - val_loss: 0.3236 - val_accuracy: 0.8529
# Epoch 19/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2102 - accuracy: 0.9400
# Epoch 00019: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2239 - accuracy: 0.9394 - val_loss: 0.3155 - val_accuracy: 0.8529
# Epoch 20/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1998 - accuracy: 0.9200
# Epoch 00020: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2119 - accuracy: 0.9394 - val_loss: 0.3087 - val_accuracy: 0.8529
# Epoch 21/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1941 - accuracy: 0.9600
# Epoch 00021: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2005 - accuracy: 0.9470 - val_loss: 0.3016 - val_accuracy: 0.8529
# Epoch 22/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1591 - accuracy: 0.9800
# Epoch 00022: val_loss did not improve from 0.29198
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1895 - accuracy: 0.9545 - val_loss: 0.2956 - val_accuracy: 0.8529
# Epoch 23/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1913 - accuracy: 0.9400
# Epoch 00023: val_loss improved from 0.29198 to 0.28994, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1797 - accuracy: 0.9545 - val_loss: 0.2899 - val_accuracy: 0.8529
# Epoch 24/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1904 - accuracy: 0.9200
# Epoch 00024: val_loss improved from 0.28994 to 0.28418, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1703 - accuracy: 0.9545 - val_loss: 0.2842 - val_accuracy: 0.8529
# Epoch 25/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1902 - accuracy: 0.9400
# Epoch 00025: val_loss improved from 0.28418 to 0.27908, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1616 - accuracy: 0.9545 - val_loss: 0.2791 - val_accuracy: 0.8529
# Epoch 26/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1766 - accuracy: 0.9600
# Epoch 00026: val_loss improved from 0.27908 to 0.27409, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1532 - accuracy: 0.9545 - val_loss: 0.2741 - val_accuracy: 0.8529
# Epoch 27/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1399 - accuracy: 0.9800
# Epoch 00027: val_loss improved from 0.27409 to 0.27251, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1453 - accuracy: 0.9621 - val_loss: 0.2725 - val_accuracy: 0.8529
# Epoch 28/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1293 - accuracy: 0.9800
# Epoch 00028: val_loss improved from 0.27251 to 0.27012, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1380 - accuracy: 0.9621 - val_loss: 0.2701 - val_accuracy: 0.8529
# Epoch 29/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1420 - accuracy: 0.9600
# Epoch 00029: val_loss improved from 0.27012 to 0.26593, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1313 - accuracy: 0.9697 - val_loss: 0.2659 - val_accuracy: 0.8529
# Epoch 30/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1304 - accuracy: 0.9600
# Epoch 00030: val_loss improved from 0.26593 to 0.26319, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1244 - accuracy: 0.9697 - val_loss: 0.2632 - val_accuracy: 0.8529
# Epoch 31/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1170 - accuracy: 0.9800
# Epoch 00031: val_loss improved from 0.26319 to 0.25790, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1185 - accuracy: 0.9848 - val_loss: 0.2579 - val_accuracy: 0.8529
# Epoch 32/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1205 - accuracy: 1.0000
# Epoch 00032: val_loss improved from 0.25790 to 0.25595, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1129 - accuracy: 0.9848 - val_loss: 0.2560 - val_accuracy: 0.8529
# Epoch 33/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0908 - accuracy: 1.0000
# Epoch 00033: val_loss improved from 0.25595 to 0.25480, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1072 - accuracy: 0.9848 - val_loss: 0.2548 - val_accuracy: 0.8529
# Epoch 34/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1000 - accuracy: 0.9800
# Epoch 00034: val_loss improved from 0.25480 to 0.25347, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1021 - accuracy: 0.9848 - val_loss: 0.2535 - val_accuracy: 0.8529
# Epoch 35/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0782 - accuracy: 0.9800
# Epoch 00035: val_loss improved from 0.25347 to 0.25034, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0970 - accuracy: 0.9848 - val_loss: 0.2503 - val_accuracy: 0.8529
# Epoch 36/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0685 - accuracy: 0.9800
# Epoch 00036: val_loss improved from 0.25034 to 0.24797, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0920 - accuracy: 0.9924 - val_loss: 0.2480 - val_accuracy: 0.8529
# Epoch 37/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1004 - accuracy: 1.0000
# Epoch 00037: val_loss improved from 0.24797 to 0.24262, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.8529
# Epoch 38/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0841 - accuracy: 1.0000
# Epoch 00038: val_loss improved from 0.24262 to 0.23742, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.8529
# Epoch 39/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0960 - accuracy: 1.0000
# Epoch 00039: val_loss improved from 0.23742 to 0.23282, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.8529
# Epoch 40/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0779 - accuracy: 1.0000
# Epoch 00040: val_loss improved from 0.23282 to 0.23012, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.8529
# Epoch 41/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0756 - accuracy: 1.0000
# Epoch 00041: val_loss improved from 0.23012 to 0.22801, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.8529
# Epoch 42/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0560 - accuracy: 1.0000
# Epoch 00042: val_loss improved from 0.22801 to 0.22729, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.8529
# Epoch 43/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0682 - accuracy: 1.0000
# Epoch 00043: val_loss improved from 0.22729 to 0.22501, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.8529
# Epoch 44/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0814 - accuracy: 1.0000
# Epoch 00044: val_loss improved from 0.22501 to 0.22421, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.8529
# Epoch 45/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0385 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 0.22421
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.8529
# Epoch 46/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0444 - accuracy: 1.0000
# Epoch 00046: val_loss improved from 0.22421 to 0.22320, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.8529
# Epoch 47/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0483 - accuracy: 1.0000
# Epoch 00047: val_loss improved from 0.22320 to 0.22265, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.8529
# Epoch 48/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.22265
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.8529
# Epoch 49/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0463 - accuracy: 1.0000
# Epoch 00049: val_loss improved from 0.22265 to 0.22188, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.8529
# Epoch 50/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0405 - accuracy: 1.0000
# Epoch 00050: val_loss improved from 0.22188 to 0.22048, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.8529
# Epoch 51/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0336 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.22048
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.8529
# Epoch 52/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0344 - accuracy: 1.0000
# Epoch 00052: val_loss improved from 0.22048 to 0.21872, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.2187 - val_accuracy: 0.8529
# Epoch 53/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0320 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 0.21872
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.8529
# Epoch 54/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0264 - accuracy: 1.0000
# Epoch 00054: val_loss improved from 0.21872 to 0.21836, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.8529
# Epoch 55/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0277 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 0.21836
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.8529
# Epoch 56/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0240 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 0.21836
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.8529
# Epoch 57/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0289 - accuracy: 1.0000
# Epoch 00057: val_loss improved from 0.21836 to 0.21832, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.8529
# Epoch 58/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0277 - accuracy: 1.0000
# Epoch 00058: val_loss improved from 0.21832 to 0.21799, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 0.8529
# Epoch 59/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0220 - accuracy: 1.0000
# Epoch 00059: val_loss improved from 0.21799 to 0.21693, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.8529
# Epoch 60/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0205 - accuracy: 1.0000
# Epoch 00060: val_loss improved from 0.21693 to 0.21652, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.8529
# Epoch 61/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0264 - accuracy: 1.0000
# Epoch 00061: val_loss improved from 0.21652 to 0.21545, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.8529
# Epoch 62/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0196 - accuracy: 1.0000
# Epoch 00062: val_loss improved from 0.21545 to 0.21273, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.8529
# Epoch 63/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 00063: val_loss improved from 0.21273 to 0.21143, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.8529
# Epoch 64/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0252 - accuracy: 1.0000
# Epoch 00064: val_loss improved from 0.21143 to 0.20884, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.8529
# Epoch 65/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 00065: val_loss improved from 0.20884 to 0.20736, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.8529
# Epoch 66/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0212 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.20736
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.8529
# Epoch 67/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0157 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.20736
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.8529
# Epoch 68/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.20736
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.8529
# Epoch 69/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0202 - accuracy: 1.0000
# Epoch 00069: val_loss improved from 0.20736 to 0.20703, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.8529
# Epoch 70/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0192 - accuracy: 1.0000
# Epoch 00070: val_loss improved from 0.20703 to 0.20446, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.8824
# Epoch 71/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 00071: val_loss improved from 0.20446 to 0.20288, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.8824
# Epoch 72/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 00072: val_loss improved from 0.20288 to 0.20267, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.8824
# Epoch 73/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.8824
# Epoch 74/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0158 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.8824
# Epoch 75/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.8824
# Epoch 76/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00076: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.8824
# Epoch 77/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.8824
# Epoch 78/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00078: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.8824
# Epoch 79/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.8824
# Epoch 80/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.8824
# Epoch 81/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 00081: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.8824
# Epoch 82/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00082: val_loss did not improve from 0.20267
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.8824
# Epoch 83/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 00083: val_loss improved from 0.20267 to 0.20229, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.8824
# Epoch 84/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00084: val_loss improved from 0.20229 to 0.20182, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.8824
# Epoch 85/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.20182
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.8824
# Epoch 86/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00086: val_loss improved from 0.20182 to 0.20113, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.8824
# Epoch 87/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00087: val_loss improved from 0.20113 to 0.20065, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.8824
# Epoch 88/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00088: val_loss improved from 0.20065 to 0.19938, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.8824
# Epoch 89/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00089: val_loss did not improve from 0.19938
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.8824
# Epoch 90/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.19938
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.8824
# Epoch 91/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00091: val_loss did not improve from 0.19938
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.8824
# Epoch 92/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 00092: val_loss did not improve from 0.19938
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.8824
# Epoch 93/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 0.19938
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.8824
# Epoch 94/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00094: val_loss improved from 0.19938 to 0.19874, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.8824
# Epoch 95/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.8824
# Epoch 96/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.8824
# Epoch 97/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.8824
# Epoch 98/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.8824
# Epoch 99/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.8824
# Epoch 100/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 0.19874
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.8824
# Epoch 101/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00101: val_loss improved from 0.19874 to 0.19850, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.8824
# Epoch 102/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00102: val_loss improved from 0.19850 to 0.19843, saving model to model/sonar.h5
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.8824
# Epoch 103/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00103: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.8824
# Epoch 104/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00104: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.8824
# Epoch 105/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00105: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.8824
# Epoch 106/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00106: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.8824
# Epoch 107/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00107: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.8824
# Epoch 108/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00108: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.8824
# Epoch 109/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00109: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.8824
# Epoch 110/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00110: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.8824
# Epoch 111/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00111: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.8824
# Epoch 112/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00112: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.8824
# Epoch 113/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00113: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.8824
# Epoch 114/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00114: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.8824
# Epoch 115/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00115: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.8824
# Epoch 116/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00116: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.8824
# Epoch 117/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00117: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.8824
# Epoch 118/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00118: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.8824
# Epoch 119/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00119: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.8824
# Epoch 120/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00120: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.8824
# Epoch 121/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00121: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.8824
# Epoch 122/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00122: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.8824
# Epoch 123/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00123: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.8824
# Epoch 124/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00124: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.8824
# Epoch 125/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00125: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.8824
# Epoch 126/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00126: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.8824
# Epoch 127/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00127: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.8824
# Epoch 128/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00128: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.8824
# Epoch 129/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00129: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.8824
# Epoch 130/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00130: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.8824
# Epoch 131/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00131: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.8824
# Epoch 132/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00132: val_loss did not improve from 0.19843
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.8824

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3861 - accuracy: 0.8571
# [0.3861370086669922, 0.8571428656578064]
